# %% [markdown]
# # **Practice Quiz: Understanding Slowness**
#
#
# ---

# %% [markdown]
# #### 1. Which of the following will an application spend the longest time retrieving data from?

# %% [markdown]
# `The network`. An application will take the longest time trying to retrieve data from the network.

# %% [markdown]
# #### 2. Which tool can you use to verify reports of 'slowness' for web pages served by a web server you manage?

# %% [markdown]
# `The ab tool`. The ab tool is an Apache Benchmark tool used to figure out how slow a web server is based on average timing of requests.

# %% [markdown]
# #### 3. If our computer running Microsoft Windows is running slow, what performance monitoring tools can we use to analyze our system resource usage to identify the bottleneck? (Check all that apply)

# %% [markdown]
# - `Performance Monitor`. Performance Monitor is a system monitoring program that provides basic CPU and memory resource measurements in Windows.
# - `Resource Monitor`. Resource Monitor is an advanced resource monitoring utility that provides data on hardware and software resources in real time.

# %% [markdown]
# #### 4. Which of the following programs is likely to run faster and more efficiently, with the least slowdown?

# %% [markdown]
# `A program small enough to fit in RAM`. Since RAM access is faster than accessing a disk or network, a program that can fit in RAM will run faster.

# %% [markdown]
# #### 5. What might cause a single application to slow down an entire system? (Check all that apply)

# %% [markdown]
# - `A memory leak`. Memory leaks happen when an application doesn't release memory when it is supposed to.
# - `Handling files that have grown too large`. If files generated by the application have grown overly large, slowdown will occur if the application needs to store a copy of the file in RAM in order to use it.
